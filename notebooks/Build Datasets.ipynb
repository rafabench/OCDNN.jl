# %% [markdown]
# Inspired in: https://playground.tensorflow.org/

# %%
using PyPlot, OCDNN
# Out:
# ┌ Info: Precompiling OCDNN [04e95dd8-2660-4c0e-9d70-3f4d10bb3a0d]
# └ @ Base loading.jl:1317

# %%
data, feat = build_dataset();

# %%
scatter(data[:,1],data[:,2], c = feat, cmap = "plasma", s = 15)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.collections.PathCollection object at 0x0000000057849588>

# %%
data, feat = build_dataset(halfspace, N_samples = 5000);

# %%
scatter(data[:,1],data[:,2], c = feat, cmap = "plasma", s = 15)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.collections.PathCollection object at 0x0000000057FBC188>

# %%
# N_noise means number of labels that will be changed randomly
data, feat = build_dataset(four_regions, N_noise = 10);

# %%
scatter(data[:,1],data[:,2], c = feat, cmap = "plasma", s = 15)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.collections.PathCollection object at 0x000000005803EF08>
