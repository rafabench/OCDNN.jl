# %% [markdown]
# Inspired in: https://playground.tensorflow.org/

# %%
using PyPlot

# %%
include("../src/build_datasets.jl")
# Out:
# four_regions (generic function with 1 method)

# %%
data, feat = build_dataset();

# %%
scatter(data[:,1],data[:,2], c = feat, cmap = "plasma", s = 15)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.collections.PathCollection object at 0x0000000057C47608>

# %%
data, feat = build_dataset(halfspace, N_samples = 5000);

# %%
scatter(data[:,1],data[:,2], c = feat, cmap = "plasma", s = 15)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.collections.PathCollection object at 0x000000005F703C08>

# %%
# N_noise means number of labels that will be changed randomly
data, feat = build_dataset(four_regions, N_noise = 10);

# %%
scatter(data[:,1],data[:,2], c = feat, cmap = "plasma", s = 15)
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.collections.PathCollection object at 0x000000000AA92B88>
