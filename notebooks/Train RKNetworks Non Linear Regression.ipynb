# %%
using Pkg
Pkg.activate("..")
# Out:
#   Activating environment at `E:\Projects\OCDNN.jl\Project.toml`

# %%
using Revise
using PyPlot, OCDNN, Printf, Random, Serialization

# %%
function in_dir(f, path::String)
    current = pwd()
    cd(path)
    f()
    cd(current)
end
# Out:
# in_dir (generic function with 1 method)

# %%
f(x) = 2x + sin(2x) + 3
# Out:
# f (generic function with 1 method)

# %%
Random.seed!(123)
xs = 0:0.02:5
ys = f.(xs) + randn(length(xs));

# %%
N = length(xs)
# Out:
# 251

# %%
dataset = reshape(collect(xs),length(xs),1), ys;

# %%
plot(xs, ys, ".")
plot(xs, f.(xs) );
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
nlayers = 2
channels = 5 # number of neurons per layer
niter = 50_000
τ=0.01;
τ_max=0.2;
stepsize = 0.1;

# %%
A_eu = reshape([0],(1,1));
w_eu = [1];
A_ie = [0 0; 1 0];
w_ie = [0.5 ;0.5];
A_kutta4 = [0 0 0 0;0.5 0 0 0;0 0.5 0 0;0 0 1 0];
w_kutta4 = 1/6*[1;2;2;1];
A_kutta3 = [0 0 0;1/2 0 0;-1 2 0];
w_kutta3 = [1/6;2/3;1/6];

# %%
rk4 = OCDNN.ExplicitRungeKutta(A_kutta4,w_kutta4,"RK4");
rk3 = OCDNN.ExplicitRungeKutta(A_kutta3,w_kutta3,"RK3");
rk2 = OCDNN.ExplicitRungeKutta(A_ie,w_ie,"RK2");
euler = OCDNN.ExplicitRungeKutta(A_eu,w_eu,"Euler");
rks = [euler,rk2,rk3,rk4];
names = [rk.name for rk in rks];

# %%
eta = x -> exp(x)/(exp(x)+1)
eta = x -> x
# Out:
# #5 (generic function with 1 method)

# %%
problem = OCDNN.Problem(tanh, eta, ys);

# %%
function cb(iter, rkmethod, nlayers, α, log, Ctrls)
    period = 10_000
    if rem(iter,period) == 0 || iter == 1
        @printf("\nMethod=%s, nlayers=%d\n",rkmethod.name,nlayers)
        @printf("Iteration no: %d\n",iter)
        @printf("Value of alpha: %7.4f\n",α);
        @printf("Residual: %8.4f\n",log.loss[end])
        @printf("Norm Grad: %8.4e\n",log.grad_norm[end]);
        if iter > 1
            @printf("Time: %8.4f\n",sum(log.time[end-period+1:end]));
        end
    end
end
# Out:
# cb (generic function with 1 method)

# %%
xs, feat = dataset;

# %%
all_results = [train_ode_dnn(dataset, nlayers, channels, rk, niter, τ, τ_max, stepsize, problem, cb) for rk in rks];
# Out:
# Method=Euler, nlayers=2
# Iteration no: 1
# Value of alpha:  0.0003
# Residual: 395.0308
# Norm Grad: 2.1177e+03
#
# Method=Euler, nlayers=2
# Iteration no: 10000
# Value of alpha:  0.0003
# Residual: 156.3848
# Norm Grad: 9.7129e-01
# Time:   7.6174
#
# Method=Euler, nlayers=2
# Iteration no: 20000
# Value of alpha:  0.0003
# Residual: 150.4033
# Norm Grad: 1.8394e+00
# Time:   4.7203
#
# Method=Euler, nlayers=2
# Iteration no: 30000
# Value of alpha:  0.0003
# Residual: 143.1517
# Norm Grad: 1.1995e+00
# Time:   4.6443
#
# Method=Euler, nlayers=2
# Iteration no: 40000
# Value of alpha:  0.0003
# Residual: 139.9992
# Norm Grad: 8.8622e-01
# Time:   4.6551
#
# Method=Euler, nlayers=2
# Iteration no: 50000
# Value of alpha:  0.0003
# Residual: 137.8656
# Norm Grad: 7.5988e-01
# Time:   4.5864
#
# Method=RK2, nlayers=2
# Iteration no: 1
# Value of alpha:  0.0003
# Residual: 472.1735
# Norm Grad: 1.8298e+03
#
# Method=RK2, nlayers=2
# Iteration no: 10000
# Value of alpha:  0.0003
# Residual: 157.3327
# Norm Grad: 1.4461e+00
# Time:   9.1932
#
# Method=RK2, nlayers=2
# Iteration no: 20000
# Value of alpha:  0.0003
# Residual: 153.7989
# Norm Grad: 1.0574e+00
# Time:   9.2220
#
# Method=RK2, nlayers=2
# Iteration no: 30000
# Value of alpha:  0.0003
# Residual: 151.6632
# Norm Grad: 6.0826e-01
# Time:   9.2811
#
# Method=RK2, nlayers=2
# Iteration no: 40000
# Value of alpha:  0.0003
# Residual: 150.3270
# Norm Grad: 6.8423e-01
# Time:   9.6125
#
# Method=RK2, nlayers=2
# Iteration no: 50000
# Value of alpha:  0.0003
# Residual: 147.5358
# Norm Grad: 1.2220e+00
# Time:   9.5460
#
# Method=RK3, nlayers=2
# Iteration no: 1
# Value of alpha:  0.0003
# Residual: 920.1150
# Norm Grad: 7.3791e+03
#
# Method=RK3, nlayers=2
# Iteration no: 10000
# Value of alpha:  0.0003
# Residual: 152.1263
# Norm Grad: 6.4774e-01
# Time:  15.3401
#
# Method=RK3, nlayers=2
# Iteration no: 20000
# Value of alpha:  0.0003
# Residual: 151.3712
# Norm Grad: 3.9345e-01
# Time:  16.1882
#
# Method=RK3, nlayers=2
# Iteration no: 30000
# Value of alpha:  0.0003
# Residual: 150.6870
# Norm Grad: 5.2888e-01
# Time:  16.0176
#
# Method=RK3, nlayers=2
# Iteration no: 40000
# Value of alpha:  0.0003
# Residual: 148.7292
# Norm Grad: 1.0514e+00
# Time:  16.0213
#
# Method=RK3, nlayers=2
# Iteration no: 50000
# Value of alpha:  0.0003
# Residual: 144.8515
# Norm Grad: 1.0643e+00
# Time:  16.1493
#
# Method=RK4, nlayers=2
# Iteration no: 1
# Value of alpha:  0.0003
# Residual: 1655.2443
# Norm Grad: 9.4838e+03
#
# Method=RK4, nlayers=2
# Iteration no: 10000
# Value of alpha:  0.0003
# Residual: 146.8001
# Norm Grad: 1.7239e+00
# Time:  24.1447
#
# Method=RK4, nlayers=2
# Iteration no: 20000
# Value of alpha:  0.0003
# Residual: 142.3932
# Norm Grad: 8.1419e-01
# Time:  24.0590
#
# Method=RK4, nlayers=2
# Iteration no: 30000
# Value of alpha:  0.0003
# Residual: 140.9585
# Norm Grad: 6.3619e-01
# Time:  22.8687
#
# Method=RK4, nlayers=2
# Iteration no: 40000
# Value of alpha:  0.0003
# Residual: 139.6735
# Norm Grad: 6.4331e-01
# Time:  22.9080
#
# Method=RK4, nlayers=2
# Iteration no: 50000
# Value of alpha:  0.0003
# Residual: 138.3877
# Norm Grad: 6.3975e-01
# Time:  22.8708

# %%
final_string = string(nlayers)*"_layers_"*string(N)*"_points_"*string(niter)*"_iter_"*string(channels)*"_channels"
traineddir = "..\\train\\Non_Linear_Regression\\"*final_string*".tmp"
serialize(traineddir, all_results)

# %%
final_string = string(nlayers)*"_layers_"*string(N)*"_points_"*string(niter)*"_iter_"*string(channels)*"_channels"
outputdir = "..\\images\\Non_Linear_Regression\\"*final_string
if !isdir(outputdir)
    mkdir(outputdir)
end

# %%
all_Ctrls,all_logs = first.(all_results),last.(all_results);

# %%
fig, axs = PyPlot.subplots()
axs.set_title("Loss")
for i in 1:4
    axs.loglog(all_logs[i].loss, label = names[i])
end
grid()
legend()
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x000000008AB90C70>

# %%
in_dir(outputdir) do
    fig.savefig("loss_rks_"*final_string*".pdf")
end

# %%
all_times = [sum(all_logs[i].time) for i in 1:4];

# %%
fig, ax = PyPlot.subplots()
ax.set_title("Time")
ax.bar(1:4,height=all_times)
ax.set_xticks(1:4)
ax.set_xticklabels(names);
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
in_dir(outputdir) do
    fig.savefig("time_rks_"*final_string*".pdf")
end

# %%
all_Ctrls_test = deepcopy.(all_Ctrls);

# %%
xs1 = collect(0:0.01:5);

# %%
Y0_test = [[x] for x in xs1];

# %%
for i in 1:4
    all_Ctrls_test[i].Y0 = hcat(Y0_test...)';
end

# %%
classifieds = [[] for i in 1:4]
for i in 1:4
    classifieds[i] = OCDNN.RKforwardstepper(all_Ctrls_test[i],rks[i],problem).Classifier;
end

# %%
# Linear Regression
β1 = sum((xs.-1/length(xs)*sum(xs)).*ys)/sum((xs.-1/length(xs)*sum(xs)).^2)
β0 = 1/length(ys)*sum(ys).-β1.*1/length(xs)*sum(xs);

# %%
fig, axs = PyPlot.subplots(2,2,figsize=(13,8))
for i in 1:4
    m,n = Int64(floor((i+1)/2)),(i%2)+1
    axs[m,n].set_title(names[i])
    axs[m,n].plot(xs, ys, ".")
    axs[m,n].plot(xs, f.(xs) , label="Original");
    #axs[m,n].plot(xs, β1 .*xs .+ β0, label="Linear Reg");
    axs[m,n].plot(xs1, classifieds[i], label="RKNN")
    axs[m,n].grid()
    axs[m,n].legend()
end
# Out:
# Figure(PyObject <Figure size 1300x800 with 4 Axes>)

# %%
in_dir(outputdir) do
    fig.savefig("Linear_Reg_rks_subplots"*final_string*".pdf")
end

# %%
fig, ax = PyPlot.subplots()
ax.plot(xs, ys, ".")
ax.plot(xs, f.(xs) , label="Original");
#ax.plot(xs, β1 .*xs .+ β0, label="Linear Reg");
for i in 1:4
    ax.plot(xs1, classifieds[i], label=names[i])
end
ax.grid()
ax.legend()
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x000000007586E940>

# %%
in_dir(outputdir) do
    fig.savefig("Linear_Reg_rks_plots"*final_string*".pdf")
end
